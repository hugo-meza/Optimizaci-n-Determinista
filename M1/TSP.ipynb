# %%
import pulp

# %%
I = [1, 2, 3, 4, 5]
C = [
    [999, 150, 120, 100, 110],
    [170, 999, 110, 90, 100],
    [200, 170, 999, 80, 100],
    [220, 190, 100, 999, 90],
    [300, 210, 180, 130, 999]
]
